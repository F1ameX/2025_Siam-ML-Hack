# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import os
import random
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')
os.chdir('../src')

# %%
stats_df = pd.read_csv('stats')
stats_df
# Out:
#                                     file  \
# 0   00e03657-8e1e-4c8c-a724-1d3c77b48510
# 1   00e4dba2-36d2-42b4-beb1-c55aed75f506
# 2   00f035b7-ad7a-4f30-9081-522a3c10805b
# 3   01a0c034-6afc-4e73-95fa-621f702a0b7d
# 4   01a530d3-6496-4515-9fbb-4f44e298fd29
# ..                                   ...
# 95  1dfaf03c-e297-4d92-a0bf-40b1a829391f
# 96  1e149fbd-41c6-4779-b87d-c5dc17fbb4c0
# 97  1e19b77c-8a0e-4749-a384-9c1e679035bf
# 98  1e4b4c18-1e32-45eb-917a-5760e33fbaca
# 99  1e7f7ecb-a6a7-40ef-9d1c-48aa96eb6c38
#
#                                              recovery  \
# 0   [[2420.9805555555554, 2438.4241666666667], [31...
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4                                                  []
# ..                                                ...
# 95                                                 []
# ...

# %%
plt.figure(figsize=(20, 10))
plt.subplot()
min_recovery_data
max_recovery_data
min
counts, bins, patches = plt.hist(data, orientation='horizontal')

plt.xlabel("Frequency")
plt.ylabel("Max difference between start and end drop points")
plt.show()

# %%
df = pd.read_csv(random.choice(os.listdir()), sep = '\\s++', names = ['time', 'pressure'])
plt.figure(figsize = (15, 10))
sns.histplot(data = df['time'], bins = df['pressure'].nunique(), kde = True)
plt.xlabel("Time (s.)")
plt.ylabel("Pressure")
plt.show()
# Out:
# /var/folders/2t/hqc5fcbd6931nt_0wxntlmyr0000gn/T/ipykernel_83212/401563422.py:1: ParserWarning:
#
# Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
